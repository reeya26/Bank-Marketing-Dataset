# %% [markdown]
# <a href="https://colab.research.google.com/github/reeya26/Bank-Marketing-Dataset/blob/main/Bank_Marketing_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Through this project, we try to analyze the factors that make a Bank Marketing campaign successful, using R language in Google Colab.
#
# Using the "rpy2" extension we can execute R commands in Google Colab

# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/janiobachmann/bank-marketing-dataset

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# Checking if the R markdown file works

# %%
# %%R
# bank <- read.csv("bank.csv")
# head(bank)
# Out:
#   age        job marital education default balance housing loan contact day
# 1  59     admin. married secondary      no    2343     yes   no unknown   5
# 2  56     admin. married secondary      no      45      no   no unknown   5
# 3  41 technician married secondary      no    1270     yes   no unknown   5
# 4  55   services married secondary      no    2476     yes   no unknown   5
# 5  54     admin. married  tertiary      no     184      no   no unknown   5
# 6  42 management  single  tertiary      no       0     yes  yes unknown   5
#   month duration campaign pdays previous poutcome deposit
# 1   may     1042        1    -1        0  unknown     yes
# 2   may     1467        1    -1        0  unknown     yes
# 3   may     1389        1    -1        0  unknown     yes
# 4   may      579        1    -1        0  unknown     yes
# 5   may      673        2    -1        0  unknown     yes
# 6   may      562        2    -1        0  unknown     yes
